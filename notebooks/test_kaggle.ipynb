# %%
import sys
sys.path.append('/kaggle/working/modules')


import os

for root, dirs, files in os.walk("/kaggle/working"):
    for file in files:
        print(os.path.join(root, file))

from pathlib import Path

for p in Path("/kaggle/working").rglob("*"):
    print(p)


from export_func import add


print(add(5, 3))
